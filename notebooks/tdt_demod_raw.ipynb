# %%
import tdt
import numpy as np
import matplotlib.pyplot as plt

# %%
file = 'R:\\DA_and_Reward\\fn55\\dPPP1-190322-093722\\Fabien-190329-101733'
file = 'R:\\DA_and_Reward\\es334\\PPP1\\tdtfiles\\Eelke-171103-094134'

# %%
data = tdt.read_block(file, t1=0, t2=360)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9d8c3dedd9c9> in <module>()
# ----> 1 data = tdt.read_block(file, t1=0, t2=360)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tdt\TDTbin2py.py in read_block(block_path, bitwise, channel, combine, headers, nodata, ranges, store, t1, t2, evtype, verbose, sortname)
#     551
#     552     if not use_outside_headers:
# --> 553         tsq_list = get_files(block_path, '.tsq')
#     554
#     555         if len(tsq_list) < 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tdt\__init__.py in get_files(dir, ext)
#      38 def get_files(dir, ext):
#      39     result = []
# ---> 40     for file in os.listdir(dir):
#      41         if file.endswith(ext):
#      42             result.append(os.path.join(dir, file))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'R:\\DA_and_Reward\\es334\\PPP1\\tdtfiles\\Eelke-171103-094134\\'

# %%
fig, ax = plt.subplots()

ax.plot(data.streams.Dv1B['data'], c='b')

# %%
raw = data.streams.Fi2r.data[5]
sig470 = data.streams.Fi2r.data[1]

# %%
np.shape(raw.data)
# Out:
# (2197266,)

# %%
fig, ax = plt.subplots()

ax.plot(raw[1000000:1000300], c='b')
ax.plot(sig470[1000000:1000300], c='r')
